# %%
import warnings
warnings.filterwarnings('ignore')

# %%
1. Add the current date to the text file today.txt as a string.

# %%
import datetime
from datetime import date
now = date.today()
curent_date = now.isoformat()
curent_date
# Out:
# '2023-06-02'

# %%
with open('today.txt','w') as file:
    file.write(curent_date)

# %%
2. Read the text file today.txt into the string today_string

# %%
with open('today.txt','r') as file:
    today_string = file.read()
today_string
# Out:
# '2023-06-02'

# %%
3. Parse the date from today_string.

# %%
from datetime import datetime
format = '%Y-%m-%d'
datetime.strptime(today_string,format)
# Out:
# datetime.datetime(2023, 6, 2, 0, 0)

# %%
4. List the files in your current directory

# %%
import os
os.listdir('.')
# Out:
# ['.anaconda',
#  '.android',
#  '.cache',
#  '.conda',
#  '.condarc',
#  '.continuum',
#  '.eclipse',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.matplotlib',
#  '.ms-ad',
#  '.p2',
#  '.vscode',
#  '.vscode-cli',
#  '.wdm',
#  'A3B18800',
#  'Admission_Predict.csv',
#  'Admission_Predict_Ver1.1.csv',
#  'adult.csv',
#  'adultcensus_mdb.ipynb',
#  'airfare',
#  'airfare.ipynb',
#  'air_Testset.xlsx',
#  'Algerian Forest Fire ML Linear Regression Prediction Model.pdf',
#  'Algerian_forest_fires_dataset_UPDATE.csv',
#  'anext.png',
#  'aplay.png',
#  'AppData',
#  'Application Data',
#  'app_rating_model.ipynb',
#  'aprevious.png',
#  'aresume.png',
#  'assignment answers.ipynb',
#  'Assignment.ipynb',
#  'Assignment3-Python.ipynb',
#  'Assignment_18_PythonBasics.ipynb',
#  'astop.png',
#  'Automation_EDA.ipynb',
#  'automation_pandas_profiling.ipynb',
#  'autoviz.ipynb',
#  'autoviz1.csv',
#  'autoviz1.ipynb',
#  'BeautifulSoup.ipynb',
#  'best_restaurants.ipynb',
#  'books.csv',
#  'books.db',
#  'C Programs',
#  'calculator_python.ipynb',
#  'calender.ipynb',
#  'Cencus_Income_Scalar.pkl',
#  'census_enc.csv',
#  'chart.xlsx',
#  'chart5.xlsx',
#  'chromedriver.exe',
#  'chromedriver_win32 (1).zip',
#  'Classification+preprocessed+data+Python.csv',
#  'Comcast_Telecom_Complaints_data.csv',
#  'Contacts',
#  'Cookies',
#  'Country-Code.xlsx',
#  'Data Science_assign.ipynb',
#  'data.xlsx',
#  'dataprep.ipynb',
#  'data_10fromat.csv',
#  'data_heart.xlsx',
#  'data_test.csv',
#  'decesion_tree.ipynb',
#  'Decision_tree.ipynb',
#  'df_test.csv',
#  'Diabetes.ipynb',
#  'DL Ques1_Group272.ipynb',
#  'Downloads',
#  'dtale.ipynb',
#  'dtree.png',
#  'eclipse',
#  'eclipse-workspace',
#  'EDA_GlobalTerrorism.ipynb',
#  'electricity1.jpg',
#  'electric_household_power_consumption_mongoDB.ipynb',
#  'elseif.ipynb',
#  'Factors_heartattack.ipynb',
#  'Favorites',
#  'flight_price.ipynb',
#  'GlobalTerrorism.csv',
#  'globalterrorismdb_071dist.csv',
#  'googleplaystore.csv',
#  'Group272_Adult_csv.ipynb',
#  'hellothere.docx',
#  'hospital_data.xlsx',
#  'HouseholdElectricSc.pkl',
#  'HouseholdElectricScalar.pkl',
#  'HouseholdElectricSci.pkl',
#  'HouseholdpowerSci.pkl',
#  'HouseholdpoweSci.pkl',
#  'household_power_consumption.csv',
#  'household_power_consumption.txt',
#  'housepower_draft.ipynb',
#  'houseprice_prediction.ipynb',
#  'House_Price.csv',
#  'house_prices.csv',
#  'IdeaProjects',
#  'IDS Assignment_Group272.ipynb',
#  'ineuron',
#  'ineuron_codes',
#  'Insurance_factor_identification.csv',
#  'IntelGraphicsProfiles',
#  'Iris.csv',
#  'Iris_d.csv',
#  'iris_flower.ipynb',
#  'ist prog.c',
#  'java_error_in_idea64_16032.log',
#  'java_error_in_idea64_23724.log',
#  'java_error_in_idea64_31288.log',
#  'Kidney Chronic Disease Prediction-Copy1.ipynb',
#  'Kidney Chronic Disease Prediction-Copy2.ipynb',
#  'Kidney Chronic Disease Prediction-Copy3.ipynb',
#  'Kidney Chronic Disease Prediction.ipynb',
#  'kidneyChronic.csv',
#  'kidney_chronic.pkl',
#  'kidney_model',
#  'Lib',
#  'Library',
#  'LICENSE_PYTHON.txt',
#  'linear_regression.ipynb',
#  'Linear_Ridge_Lasso_ElasticNet.ipynb',
#  'Links',
#  'Local Settings',
#  'Logistic_Regression_Algerian_Forest_Fires_Prediction.ipynb',
#  'machinelearning.jpg',
#  'main.py',
#  'market_basket.ipynb',
#  'market_basket_prediction.ipynb',
#  'MBA-IT.pdf',
#  'merge.ipynb',
#  'Microsoft',
#  'Microsoft VS Code',
#  'mlmodel.py',
#  'ML_Assignment1.ipynb',
#  'mongodb-power consumption .ipynb',
#  'mongodb_houseelectric.ipynb',
#  'mongodb_svr_elasticnet_ridge_lasso_linear-Copy2.ipynb',
#  'Music',
#  'music1.jpeg',
#  'musicc.png',
#  'musicplayer_list_python.ipynb',
#  'music_list',
#  'My Documents',
#  'NetHood',
#  'next.png',
#  'NLP_Assignment1_Grp272.ipynb',
#  'NSE-TATAGLOBAL.csv',
#  'NTUSER.DAT',
#  'ntuser.dat.LOG1',
#  'ntuser.dat.LOG2',
#  'NTUSER.DAT{8dbefafb-ddbb-11ed-a32b-d681fd7db878}.TM.blf',
#  'NTUSER.DAT{8dbefafb-ddbb-11ed-a32b-d681fd7db878}.TMContainer00000000000000000001.regtrans-ms',
#  'NTUSER.DAT{8dbefafb-ddbb-11ed-a32b-d681fd7db878}.TMContainer00000000000000000002.regtrans-ms',
#  'ntuser.ini',
#  'numpy array.ipynb',
#  'OneDrive',
#  'opencv',
#  'opencv-4.6.0-vc14_vc15.exe',
#  'orders3.csv',
#  'orders5.csv',
#  'orders_2020_2021_DataSets.csv',
#  'orders_2020_2021_DataSet_updated.csv',
#  'order_review.ipynb',
#  'output.html',
#  'pause.jpeg',
#  'PDFfile.pdf',
#  'pdfword.docx',
#  'Pencil_sketch.ipynb',
#  'pkgs',
#  'PlayList',
#  'Plotting National Flag.ipynb',
#  'predicted_hours.ipynb',
#  'Predicting house prices using multiple linear regression.ipynb',
#  'Predicting salary for different experience levels .ipynb',
#  'PrintHood',
#  'Programming_Assignment1.ipynb',
#  'Programming_Assignment10.ipynb',
#  'Programming_Assignment2.ipynb',
#  'Programming_Assignment3.ipynb',
#  'Programming_Assignment4.ipynb',
#  'Programming_Assignment5.ipynb',
#  'Programming_Assignment6.ipynb',
#  'Programming_Assignment7.ipynb',
#  'Programming_Assignment8.ipynb',
#  'Programming_Assignment9.ipynb',
#  'pyodbc.pyi',
#  'python',
#  'python program to display charts in excel and extract column from xml , pdf , word file and display in excel.ipynb',
#  'Python Programss',
#  'python1.xlsx',
#  'python39.dll',
#  'Python_1.ipynb',
#  'Python_10.ipynb',
#  'Python_11.ipynb',
#  'Python_12_assign.ipynb',
#  'Python_13_assign.ipynb',
#  'Python_14.ipynb',
#  'Python_15_assign.ipynb',
#  'Python_16_assign.ipynb',
#  'Python_17.ipynb',
#  'python_19.ipynb',
#  'Python_2.ipynb',
#  'python_20.ipynb',
#  'python_21.ipynb',
#  'Python_4.ipynb',
#  'Python_5.ipynb',
#  'Python_6.ipynb',
#  'Python_7..ipynb',
#  'Python_8.ipynb',
#  'Python_9.ipynb',
#  'python_calculator.ipynb',
#  'python_enter1_plot.png',
#  'python_plot.xlsx',
#  'python_pretty_plot.png',
#  'Recent',
#  'reg_mongodb-Copy3.ipynb',
#  'reg_mongodb.ipynb',
#  'reverse.ipynb',
#  'review_dataset (1).csv',
#  'ritikadata',
#  'ROC_AUC .ipynb',
#  'runs',
#  'Saved Games',
#  'Scripts',
#  'Searches',
#  'SendTo',
#  'songs.csv.7z',
#  'spark',
#  'Speed_typing_test_in_python.ipynb',
#  'sqltutorial.ipynb',
#  'Start Menu',
#  'stocks.ipynb',
#  'Stock_prediction.ipynb',
#  'student_chart.xlsx',
#  'SVM_Kernels.ipynb',
#  'SVM_winedatasets.ipynb',
#  'SVR_admissionprediction.ipynb',
#  'sweetviz.ipynb',
#  'temp.json',
#  'Templates',
#  'test.txt',
#  'To  plot graphs for analysis on various parameters.ipynb',
#  'To display graphs for various analysis.ipynb',
#  'today.txt',
#  'Tracing',
#  'train_titanic2.csv',
#  'Untitled.ipynb',
#  'Untitled1.ipynb',
#  'Untitled2-Copy1.ipynb',
#  'variable description.xlsx',
#  'variable_description1.xlsx',
#  'vehicle-detection-16',
#  'Videos',
#  'weatherAUS.ipynb',
#  'wine_dataset.csv',
#  'wine_dataset_prediction.ipynb',
#  'Wordfiles.docx',
#  'Wordfiles2.docx',
#  'Wordfiles2.pdf',
#  'Word_doc.docx',
#  'yolov8m.pt',
#  'yolov8n.pt',
#  '~$air_Testset.xlsx']

# %%
5. Create a list of all of the files in your parent directory (minimum five files should be available).

# %%
os.listdir('.')
# Out:
# ['.anaconda',
#  '.android',
#  '.cache',
#  '.conda',
#  '.condarc',
#  '.continuum',
#  '.eclipse',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.matplotlib',
#  '.ms-ad',
#  '.p2',
#  '.vscode',
#  '.vscode-cli',
#  '.wdm',
#  'A3B18800',
#  'Admission_Predict.csv',
#  'Admission_Predict_Ver1.1.csv',
#  'adult.csv',
#  'adultcensus_mdb.ipynb',
#  'airfare',
#  'airfare.ipynb',
#  'air_Testset.xlsx',
#  'Algerian Forest Fire ML Linear Regression Prediction Model.pdf',
#  'Algerian_forest_fires_dataset_UPDATE.csv',
#  'anext.png',
#  'aplay.png',
#  'AppData',
#  'Application Data',
#  'app_rating_model.ipynb',
#  'aprevious.png',
#  'aresume.png',
#  'assignment answers.ipynb',
#  'Assignment.ipynb',
#  'Assignment3-Python.ipynb',
#  'Assignment_18_PythonBasics.ipynb',
#  'astop.png',
#  'Automation_EDA.ipynb',
#  'automation_pandas_profiling.ipynb',
#  'autoviz.ipynb',
#  'autoviz1.csv',
#  'autoviz1.ipynb',
#  'BeautifulSoup.ipynb',
#  'best_restaurants.ipynb',
#  'books.csv',
#  'books.db',
#  'C Programs',
#  'calculator_python.ipynb',
#  'calender.ipynb',
#  'Cencus_Income_Scalar.pkl',
#  'census_enc.csv',
#  'chart.xlsx',
#  'chart5.xlsx',
#  'chromedriver.exe',
#  'chromedriver_win32 (1).zip',
#  'Classification+preprocessed+data+Python.csv',
#  'Comcast_Telecom_Complaints_data.csv',
#  'Contacts',
#  'Cookies',
#  'Country-Code.xlsx',
#  'Data Science_assign.ipynb',
#  'data.xlsx',
#  'dataprep.ipynb',
#  'data_10fromat.csv',
#  'data_heart.xlsx',
#  'data_test.csv',
#  'decesion_tree.ipynb',
#  'Decision_tree.ipynb',
#  'df_test.csv',
#  'Diabetes.ipynb',
#  'DL Ques1_Group272.ipynb',
#  'Downloads',
#  'dtale.ipynb',
#  'dtree.png',
#  'eclipse',
#  'eclipse-workspace',
#  'EDA_GlobalTerrorism.ipynb',
#  'electricity1.jpg',
#  'electric_household_power_consumption_mongoDB.ipynb',
#  'elseif.ipynb',
#  'Factors_heartattack.ipynb',
#  'Favorites',
#  'flight_price.ipynb',
#  'GlobalTerrorism.csv',
#  'globalterrorismdb_071dist.csv',
#  'googleplaystore.csv',
#  'Group272_Adult_csv.ipynb',
#  'hellothere.docx',
#  'hospital_data.xlsx',
#  'HouseholdElectricSc.pkl',
#  'HouseholdElectricScalar.pkl',
#  'HouseholdElectricSci.pkl',
#  'HouseholdpowerSci.pkl',
#  'HouseholdpoweSci.pkl',
#  'household_power_consumption.csv',
#  'household_power_consumption.txt',
#  'housepower_draft.ipynb',
#  'houseprice_prediction.ipynb',
#  'House_Price.csv',
#  'house_prices.csv',
#  'IdeaProjects',
#  'IDS Assignment_Group272.ipynb',
#  'ineuron',
#  'ineuron_codes',
#  'Insurance_factor_identification.csv',
#  'IntelGraphicsProfiles',
#  'Iris.csv',
#  'Iris_d.csv',
#  'iris_flower.ipynb',
#  'ist prog.c',
#  'java_error_in_idea64_16032.log',
#  'java_error_in_idea64_23724.log',
#  'java_error_in_idea64_31288.log',
#  'Kidney Chronic Disease Prediction-Copy1.ipynb',
#  'Kidney Chronic Disease Prediction-Copy2.ipynb',
#  'Kidney Chronic Disease Prediction-Copy3.ipynb',
#  'Kidney Chronic Disease Prediction.ipynb',
#  'kidneyChronic.csv',
#  'kidney_chronic.pkl',
#  'kidney_model',
#  'Lib',
#  'Library',
#  'LICENSE_PYTHON.txt',
#  'linear_regression.ipynb',
#  'Linear_Ridge_Lasso_ElasticNet.ipynb',
#  'Links',
#  'Local Settings',
#  'Logistic_Regression_Algerian_Forest_Fires_Prediction.ipynb',
#  'machinelearning.jpg',
#  'main.py',
#  'market_basket.ipynb',
#  'market_basket_prediction.ipynb',
#  'MBA-IT.pdf',
#  'merge.ipynb',
#  'Microsoft',
#  'Microsoft VS Code',
#  'mlmodel.py',
#  'ML_Assignment1.ipynb',
#  'mongodb-power consumption .ipynb',
#  'mongodb_houseelectric.ipynb',
#  'mongodb_svr_elasticnet_ridge_lasso_linear-Copy2.ipynb',
#  'Music',
#  'music1.jpeg',
#  'musicc.png',
#  'musicplayer_list_python.ipynb',
#  'music_list',
#  'My Documents',
#  'NetHood',
#  'next.png',
#  'NLP_Assignment1_Grp272.ipynb',
#  'NSE-TATAGLOBAL.csv',
#  'NTUSER.DAT',
#  'ntuser.dat.LOG1',
#  'ntuser.dat.LOG2',
#  'NTUSER.DAT{8dbefafb-ddbb-11ed-a32b-d681fd7db878}.TM.blf',
#  'NTUSER.DAT{8dbefafb-ddbb-11ed-a32b-d681fd7db878}.TMContainer00000000000000000001.regtrans-ms',
#  'NTUSER.DAT{8dbefafb-ddbb-11ed-a32b-d681fd7db878}.TMContainer00000000000000000002.regtrans-ms',
#  'ntuser.ini',
#  'numpy array.ipynb',
#  'OneDrive',
#  'opencv',
#  'opencv-4.6.0-vc14_vc15.exe',
#  'orders3.csv',
#  'orders5.csv',
#  'orders_2020_2021_DataSets.csv',
#  'orders_2020_2021_DataSet_updated.csv',
#  'order_review.ipynb',
#  'output.html',
#  'pause.jpeg',
#  'PDFfile.pdf',
#  'pdfword.docx',
#  'Pencil_sketch.ipynb',
#  'pkgs',
#  'PlayList',
#  'Plotting National Flag.ipynb',
#  'predicted_hours.ipynb',
#  'Predicting house prices using multiple linear regression.ipynb',
#  'Predicting salary for different experience levels .ipynb',
#  'PrintHood',
#  'Programming_Assignment1.ipynb',
#  'Programming_Assignment10.ipynb',
#  'Programming_Assignment2.ipynb',
#  'Programming_Assignment3.ipynb',
#  'Programming_Assignment4.ipynb',
#  'Programming_Assignment5.ipynb',
#  'Programming_Assignment6.ipynb',
#  'Programming_Assignment7.ipynb',
#  'Programming_Assignment8.ipynb',
#  'Programming_Assignment9.ipynb',
#  'pyodbc.pyi',
#  'python',
#  'python program to display charts in excel and extract column from xml , pdf , word file and display in excel.ipynb',
#  'Python Programss',
#  'python1.xlsx',
#  'python39.dll',
#  'Python_1.ipynb',
#  'Python_10.ipynb',
#  'Python_11.ipynb',
#  'Python_12_assign.ipynb',
#  'Python_13_assign.ipynb',
#  'Python_14.ipynb',
#  'Python_15_assign.ipynb',
#  'Python_16_assign.ipynb',
#  'Python_17.ipynb',
#  'python_19.ipynb',
#  'Python_2.ipynb',
#  'python_20.ipynb',
#  'python_21.ipynb',
#  'Python_4.ipynb',
#  'Python_5.ipynb',
#  'Python_6.ipynb',
#  'Python_7..ipynb',
#  'Python_8.ipynb',
#  'Python_9.ipynb',
#  'python_calculator.ipynb',
#  'python_enter1_plot.png',
#  'python_plot.xlsx',
#  'python_pretty_plot.png',
#  'Recent',
#  'reg_mongodb-Copy3.ipynb',
#  'reg_mongodb.ipynb',
#  'reverse.ipynb',
#  'review_dataset (1).csv',
#  'ritikadata',
#  'ROC_AUC .ipynb',
#  'runs',
#  'Saved Games',
#  'Scripts',
#  'Searches',
#  'SendTo',
#  'songs.csv.7z',
#  'spark',
#  'Speed_typing_test_in_python.ipynb',
#  'sqltutorial.ipynb',
#  'Start Menu',
#  'stocks.ipynb',
#  'Stock_prediction.ipynb',
#  'student_chart.xlsx',
#  'SVM_Kernels.ipynb',
#  'SVM_winedatasets.ipynb',
#  'SVR_admissionprediction.ipynb',
#  'sweetviz.ipynb',
#  'temp.json',
#  'Templates',
#  'test.txt',
#  'To  plot graphs for analysis on various parameters.ipynb',
#  'To display graphs for various analysis.ipynb',
#  'today.txt',
#  'Tracing',
#  'train_titanic2.csv',
#  'Untitled.ipynb',
#  'Untitled1.ipynb',
#  'Untitled2-Copy1.ipynb',
#  'variable description.xlsx',
#  'variable_description1.xlsx',
#  'vehicle-detection-16',
#  'Videos',
#  'weatherAUS.ipynb',
#  'wine_dataset.csv',
#  'wine_dataset_prediction.ipynb',
#  'Wordfiles.docx',
#  'Wordfiles2.docx',
#  'Wordfiles2.pdf',
#  'Word_doc.docx',
#  'yolov8m.pt',
#  'yolov8n.pt',
#  '~$air_Testset.xlsx']

# %%
6. Use multiprocessing to create three separate processes. Make each one wait a random number of
seconds between one and five, print the current time, and then exit.

# %%
import multiprocessing

def printsec(seconds):
    from datetime import datetime
    from time import sleep
    sleep(seconds)
    print('wait', seconds, 'seconds, time is', datetime.utcnow())
    
if __name__ == '__main__':
    import random    
    for n in range(3):
        seconds = random.random()
        proc = multiprocessing.Process(target=printsec, args=(seconds,))
        proc.start()

# %%
# !python Programming_Assignment1.ipynb
# Out:
# Traceback (most recent call last):
#   File "C:\Users\nawin\Programming_Assignment1.ipynb", line 179, in <module>
#     "execution_count": null,
# NameError: name 'null' is not defined

# %%
7. Create a date object of your day of birth.

# %%
my_dob = date(2021,2,28)
my_dob
# Out:
# datetime.date(2021, 2, 28)

# %%
8. What day of the week was your day of birth?

# %%
my_dob.weekday()
# Out:
# 6

# %%
9. When will you be (or when were you) 10,000 days old?

# %%
from datetime import timedelta
day10000 = my_dob + timedelta(days=10000)
day10000
